# %% [markdown]
# #### Creating Dataframe

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("genz_social_media_usage_1M.csv")
df
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 0        19    Male  Australia           2.658617         Snapchat
# 1        16  Female        USA           5.685387          Twitter
# 2        25  Female        NaN           2.782420           TikTok
# 3        27    Male      India           3.486598          YouTube
# 4        23  Female      India           3.748829           TikTok
# ...     ...     ...        ...                ...              ...
# 999995   21    Male      India           3.097065         Snapchat
# 999996   14    Male      India           3.663561        Instagram
# 999997   20    Male      India           4.474618          YouTube
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 0                        4         Education            29.222443
# ...

# %%
df.shape
# Out:
# (1000000, 12)

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female        NaN           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443          0.0
# 1                   3    Socializing            32.464726          1.0
# 2                   2            NaN            18.170204          NaN
# 3                   4      Education            22.493804          1.0
# 4                   1  Entertainment            27.358410          1.0
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %%
df.tail()
# Out:
#         age  gender  country  daily_usage_hours primary_platform  \
# 999995   21    Male    India           3.097065         Snapchat
# 999996   14    Male    India           3.663561        Instagram
# 999997   20    Male    India           4.474618          YouTube
# 999998   24  Female  Germany           7.829924          YouTube
# 999999   13    Male   Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 999995                   4     Entertainment            21.158532
# 999996                   1         Education            26.312119
# 999997                   2       Socializing            13.623681
# 999998                   2  Content Creation            15.789750
# 999999                   1       Socializing            26.397129
#
#         night_usage  mental_health_score addiction_level  \
# 999995          1.0             7.230186          Medium
# 999996          1.0             8.273996          Medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   age                       1000000 non-null  int64
#  1   gender                    1000000 non-null  object
#  2   country                   999997 non-null   object
#  3   daily_usage_hours         999997 non-null   float64
#  4   primary_platform          999995 non-null   object
#  5   num_platforms_used        1000000 non-null  int64
#  6   purpose                   999997 non-null   object
#  7   avg_session_minutes       999999 non-null   float64
#  8   night_usage               999999 non-null   float64
#  9   mental_health_score       999997 non-null   float64
#  10  addiction_level           999995 non-null   object
#  11  screen_time_before_sleep  999996 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 91.6+ MB

# %%
df.describe()
# Out:
#                   age  daily_usage_hours  num_platforms_used  \
# count  1000000.000000      999997.000000      1000000.000000
# mean        19.994629           3.515051            2.999482
# std          4.322119           1.469334            1.414649
# min         13.000000           0.500000            1.000000
# 25%         16.000000           2.493985            2.000000
# 50%         20.000000           3.503303            3.000000
# 75%         24.000000           4.513020            4.000000
# max         27.000000          40.466860           15.000000
#
#        avg_session_minutes    night_usage  mental_health_score  \
# count        999999.000000  999999.000000        999997.000000
# mean             25.088828       0.600003             7.170674
# std               9.794249       0.490897             1.503886
# min               5.000000       0.000000             1.000000
# 25%              18.257276       0.000000             6.147372
# ...

# %%
df.value_counts()
# Out:
# age  gender  country    daily_usage_hours  primary_platform  num_platforms_used  purpose           avg_session_minutes  night_usage  mental_health_score  addiction_level  screen_time_before_sleep
# 13   Female  Australia  0.500000           Instagram         1                   Entertainment     11.984118            0.0          9.016778             Low              43.178599                   1
# 22   Other   USA        3.108601           Twitter           2                   Socializing       37.968784            1.0          7.588087             Medium           43.891739                   1
#                         3.127979           TikTok            3                   Entertainment     37.212430            1.0          7.596964             Medium           46.352729                   1
# ...

# %%
print(df.columns)
# Out:
# Index(['age', 'gender', 'country', 'daily_usage_hours', 'primary_platform',
#        'num_platforms_used', 'purpose', 'avg_session_minutes', 'night_usage',
#        'mental_health_score', 'addiction_level', 'screen_time_before_sleep'],
#       dtype='object')

# %%
df.sort_values("age")
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 999999   13    Male     Canada           5.313645           TikTok
# 727347   13   Other     Canada           4.808825           TikTok
# 163361   13  Female    Germany           3.543437        Instagram
# 163351   13  Female        USA           1.853048          YouTube
# 727377   13  Female      India           4.870689          YouTube
# ...     ...     ...        ...                ...              ...
# 592322   27    Male         UK           3.215141           TikTok
# 244883   27  Female  Australia           2.867743         Snapchat
# 951137   27  Female      India           3.547717          Twitter
# 528651   27   Other     Canada           3.404503           TikTok
# 402686   27  Female      India           3.738036           TikTok
#
#         num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 999999                   1    Socializing            26.397129          1.0
# ...

# %%
# selection and indexing
df['age']
# Out:
# 0         19
# 1         16
# 2         25
# 3         27
# 4         23
#           ..
# 999995    21
# 999996    14
# 999997    20
# 999998    24
# 999999    13
# Name: age, Length: 1000000, dtype: int64

# %%
df[['age','country']]
# Out:
#         age    country
# 0        19  Australia
# 1        16        USA
# 2        25        NaN
# 3        27      India
# 4        23      India
# ...     ...        ...
# 999995   21      India
# 999996   14      India
# 999997   20      India
# 999998   24    Germany
# 999999   13     Canada
#
# [1000000 rows x 2 columns]

# %%
# to extract row 
df.loc[[2]]
# Out:
#    age  gender country  daily_usage_hours primary_platform  \
# 2   25  Female     NaN            2.78242           TikTok
#
#    num_platforms_used purpose  avg_session_minutes  night_usage  \
# 2                   2     NaN            18.170204          NaN
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 2             6.035397             NaN                 62.524625

# %%
# to extraxt portion of row and column
df.loc[[0,1,2,3]][['age','daily_usage_hours','primary_platform']]
# Out:
#    age  daily_usage_hours primary_platform
# 0   19           2.658617         Snapchat
# 1   16           5.685387          Twitter
# 2   25           2.782420           TikTok
# 3   27           3.486598          YouTube

# %%
# age >= 25 and country is USA
df[(df['age']<=18) & (df['country'] == 'USA')]
# Out:
#         age  gender country  daily_usage_hours primary_platform  \
# 1        16  Female     USA           5.685387          Twitter
# 10       15  Female     USA           1.737296          Twitter
# 19       15  Female     USA           4.887226        Instagram
# 56       15    Male     USA           2.845691        Instagram
# 58       17    Male     USA           4.176839          Twitter
# ...     ...     ...     ...                ...              ...
# 999960   16  Female     USA           2.426716        Instagram
# 999962   13  Female     USA           7.273087         Snapchat
# 999979   17  Female     USA           3.982817        Instagram
# 999981   13  Female     USA           4.032096          YouTube
# 999994   14   Other     USA           2.568001         Snapchat
#
#         num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 1                        3    Socializing            32.464726          1.0
# ...

# %%
df[(df['age']<=18) & (df['country'] == 'USA') & (df['primary_platform'] == 'Instagram')]
# Out:
#         age  gender country  daily_usage_hours primary_platform  \
# 19       15  Female     USA           4.887226        Instagram
# 56       15    Male     USA           2.845691        Instagram
# 84       16  Female     USA           4.008622        Instagram
# 142      13  Female     USA           4.683081        Instagram
# 145      15    Male     USA           2.971981        Instagram
# ...     ...     ...     ...                ...              ...
# 999911   13  Female     USA           2.823330        Instagram
# 999928   13    Male     USA           3.839075        Instagram
# 999942   14  Female     USA           2.295873        Instagram
# 999960   16  Female     USA           2.426716        Instagram
# 999979   17  Female     USA           3.982817        Instagram
#
#         num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 19                       2      Education            31.862099          1.0
# ...

# %% [markdown]
# ### Missing Value

# %%
df.isnull()
# Out:
#           age  gender  country  daily_usage_hours  primary_platform  \
# 0       False   False    False              False             False
# 1       False   False    False              False             False
# 2       False   False     True              False             False
# 3       False   False    False              False             False
# 4       False   False    False              False             False
# ...       ...     ...      ...                ...               ...
# 999995  False   False    False              False             False
# 999996  False   False    False              False             False
# 999997  False   False    False              False             False
# 999998  False   False    False              False             False
# 999999  False   False    False              False             False
#
#         num_platforms_used  purpose  avg_session_minutes  night_usage  \
# 0                    False    False                False        False
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# country                     3
# daily_usage_hours           3
# primary_platform            5
# num_platforms_used          0
# purpose                     3
# avg_session_minutes         1
# night_usage                 1
# mental_health_score         3
# addiction_level             5
# screen_time_before_sleep    4
# dtype: int64

# %%
# to remove null value
# thresh=2" means if row has two non null value then and then only it remove row which has missing value 
# df.dropna(thresh=6)

# %%
# df.fillna(0,inplace=True)

# %%
df
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 0        19    Male  Australia           2.658617         Snapchat
# 1        16  Female        USA           5.685387          Twitter
# 2        25  Female        NaN           2.782420           TikTok
# 3        27    Male      India           3.486598          YouTube
# 4        23  Female      India           3.748829           TikTok
# ...     ...     ...        ...                ...              ...
# 999995   21    Male      India           3.097065         Snapchat
# 999996   14    Male      India           3.663561        Instagram
# 999997   20    Male      India           4.474618          YouTube
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 0                        4         Education            29.222443
# ...
